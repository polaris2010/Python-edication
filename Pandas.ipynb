# %% [markdown]
# # Практикум Python
#
#
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM.png" align="right" style="height: 200px;"/>

# %% [markdown]
# #Работа с табличными данными. Pandas

# %% [markdown]
# В этом ноутбуке мы познакомимся с основными фичами `pandas`. Эта библиотека огромна, поэтому мы сможем лишь немного поиграться с доступной функциональностью. Для детального ознакомления стоит почитать [документацию](https://pandas.pydata.org/docs/reference/index.html)

# %% [markdown]
# # Первое знакомство

# %% [markdown]
# Импортируем `pandas`:

# %%
import pandas as pd  # Стандартный алиас для pandas

# %% [markdown]
# Читаем датасет из csv-файла:

# %%
coins = pd.read_csv('/content/coins.csv')

# %%
pd.read_csv?

# %% [markdown]
# Посмотрим что хранится в переменной:

# %%
coins
# Out:
#              date       price  txCount      txVolume  activeAddresses symbol  \
# 0      2013-04-28  135.300000  41702.0  6.879868e+07         117984.0    BTC
# 1      2013-04-28    4.300000   9174.0  4.431952e+07          17216.0    LTC
# 2      2013-04-29  134.440000  51602.0  1.138128e+08          86925.0    BTC
# 3      2013-04-29    4.370000   9275.0  3.647810e+07          18395.0    LTC
# 4      2013-04-30  144.000000  47450.0  8.426632e+07          76871.0    BTC
# ...           ...         ...      ...           ...              ...    ...
# 37583  2018-06-06    0.293325   4830.0  2.312763e+05            659.0    XLM
# 37584  2018-06-06    0.039586   7205.0  4.947760e+06          18228.0    XVG
# 37585  2018-06-06  239.760000  10687.0  3.986308e+07          96516.0    ZEC
# 37586  2018-06-06    0.127555   1313.0  1.596436e+07            733.0    ZIL
# 37587  2018-06-06    1.270000    795.0  6.094435e+06            599.0    ZRX
#
#            name        open        high         low       close      volume  \
# 0       Bitcoin  135.300000  135.980000  132.100000  134.210000         0.0
# 1      Litecoin    4.300000    4.400000    4.180000    4.350000         0.0
# 2       Bitcoin  134.440000  147.490000  134.000000  144.540000         0.0
# 3      Litecoin    4.370000    4.570000    4.230000    4.380000         0.0
# 4       Bitcoin  144.000000  146.930000  134.050000  139.000000         0.0
# ...         ...         ...         ...         ...         ...         ...
# 37583   Stellar    0.293325    0.299955    0.289500    0.298269  51165000.0
# 37584     Verge    0.039586    0.039737    0.037680    0.038797   9307450.0
# 37585     Zcash  239.750000  240.340000  229.210000  236.050000  56887000.0
# 37586   Zilliqa    0.127555    0.133254    0.124194    0.131766  54667900.0
# 37587        0x    1.270000    1.340000    1.250000    1.330000  17778000.0
#
#              market
# 0      1.500520e+09
# 1      7.377340e+07
# 2      1.491160e+09
# 3      7.495270e+07
# 4      1.597780e+09
# ...             ...
# 37583  5.450080e+09
# 37584  5.959400e+08
# 37585  9.769940e+08
# 37586  9.348810e+08
# 37587  6.741510e+08
#
# [37588 rows x 13 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['txCount'].plot(kind='hist', bins=20, title='txCount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['txVolume'].plot(kind='hist', bins=20, title='txVolume')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['activeAddresses'].plot(kind='hist', bins=20, title='activeAddresses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='price', y='txCount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='txCount', y='txVolume', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='txVolume', y='activeAddresses', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='activeAddresses', y='open', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['txCount']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('txCount')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['txVolume']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('txVolume')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['activeAddresses']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('activeAddresses')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['txCount'].plot(kind='line', figsize=(8, 4), title='txCount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['txVolume'].plot(kind='line', figsize=(8, 4), title='txVolume')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['activeAddresses'].plot(kind='line', figsize=(8, 4), title='activeAddresses')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_27.plot(kind='scatter', x='price', y='txCount', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Посмотрим на тип переменной:

# %%
type(coins)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Поясним значения, хранящиеся в колонках:
#  - *date* - дата измерений
#  - *name* - полное название монеты
#  - *symbol* - сокращенное название монеты
#  - *price* - средняя цена монеты за торговый день в USD
#  - *txCount* - количество транзакций в сети данной монеты
#  - *txVolume* - объем монет переведенных между адресами в сети данной монеты
#  - *activeAddresses* - количество адресов совершавших а данный день транзации в сети данной монеты
#  - *open* - цена монеты в начале торгов данного дня
#  - *close* - цена монеты в конце торгов данного дня
#  - *high* - самая высокая цена данной монеты в течение данного торгового дня
#  - *low* - самая низкая цена данной монеты в течение данного торгового дня
#  - *volume* - объем торгов данной монетой на биржах в данный день
#  - *market* - капитализация данной монеты в данный день

# %% [markdown]
# По выводу можно получить общее представление о таблице. Видно, что в таблице могут храниться как числовые так и категориальные (строковые) данные, количество строк и столбцов. Всю эту информацию и многое другое можно получить и в коде.

# %% [markdown]
# Для удобства мы далее ограничим размер вывода pandas в jupyter notebook:

# %%
pd.set_option('display.max_rows', 10)

# %% [markdown]
# Можем посмотреть на размер таблицы:

# %%
coins.shape
# Out:
# (37588, 13)

# %% [markdown]
# Чтобы вывести лишь несколько первых строк таблицы, воспользуемся методом `head`:

# %%
coins.tail(7)
# Out:
#              date       price  txCount      txVolume  activeAddresses symbol  \
# 37581  2018-06-06   12.120000    200.0  5.920692e+05            209.0    WTC
# 37582  2018-06-06    0.252141   6613.0  3.267675e+06           3231.0    XEM
# 37583  2018-06-06    0.293325   4830.0  2.312763e+05            659.0    XLM
# 37584  2018-06-06    0.039586   7205.0  4.947760e+06          18228.0    XVG
# 37585  2018-06-06  239.760000  10687.0  3.986308e+07          96516.0    ZEC
# 37586  2018-06-06    0.127555   1313.0  1.596436e+07            733.0    ZIL
# 37587  2018-06-06    1.270000    795.0  6.094435e+06            599.0    ZRX
#
#               name        open        high         low       close  \
# 37581  Waltonchain   12.120000   12.920000   11.820000   12.900000
# 37582          NEM    0.252141    0.252469    0.245758    0.250975
# 37583      Stellar    0.293325    0.299955    0.289500    0.298269
# 37584        Verge    0.039586    0.039737    0.037680    0.038797
# 37585        Zcash  239.750000  240.340000  229.210000  236.050000
# 37586      Zilliqa    0.127555    0.133254    0.124194    0.131766
# 37587           0x    1.270000    1.340000    1.250000    1.330000
#
#            volume        market
# 37581  11264200.0  3.775560e+08
# 37582  16446800.0  2.269270e+09
# 37583  51165000.0  5.450080e+09
# 37584   9307450.0  5.959400e+08
# 37585  56887000.0  9.769940e+08
# 37586  54667900.0  9.348810e+08
# 37587  17778000.0  6.741510e+08
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['txCount'].plot(kind='hist', bins=20, title='txCount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['txVolume'].plot(kind='hist', bins=20, title='txVolume')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['activeAddresses'].plot(kind='hist', bins=20, title='activeAddresses')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('symbol').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='price', y='txCount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='txCount', y='txVolume', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='txVolume', y='activeAddresses', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='activeAddresses', y='open', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('symbol')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='symbol', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['price']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('price')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['txCount']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('symbol')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='symbol', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('txCount')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['txCount']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('txCount')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['txCount'].plot(kind='line', figsize=(8, 4), title='txCount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['txVolume'].plot(kind='line', figsize=(8, 4), title='txVolume')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['activeAddresses'].plot(kind='line', figsize=(8, 4), title='activeAddresses')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['name'].value_counts()
#     for x_label, grp in _df_18.groupby('symbol')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('symbol')
# _ = plt.ylabel('name')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['symbol'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='price', y='symbol', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='price', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['symbol'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='txCount', y='symbol', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='txCount', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
coins.head()
# Out:
#          date   price  txCount      txVolume  activeAddresses symbol  \
# 0  2013-04-28  135.30  41702.0  6.879868e+07         117984.0    BTC
# 1  2013-04-28    4.30   9174.0  4.431952e+07          17216.0    LTC
# 2  2013-04-29  134.44  51602.0  1.138128e+08          86925.0    BTC
# 3  2013-04-29    4.37   9275.0  3.647810e+07          18395.0    LTC
# 4  2013-04-30  144.00  47450.0  8.426632e+07          76871.0    BTC
#
#        name    open    high     low   close  volume        market
# 0   Bitcoin  135.30  135.98  132.10  134.21     0.0  1.500520e+09
# 1  Litecoin    4.30    4.40    4.18    4.35     0.0  7.377340e+07
# 2   Bitcoin  134.44  147.49  134.00  144.54     0.0  1.491160e+09
# 3  Litecoin    4.37    4.57    4.23    4.38     0.0  7.495270e+07
# 4   Bitcoin  144.00  146.93  134.05  139.00     0.0  1.597780e+09

# %%
type(coins.head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Чтобы посмотреть информацию о содержимом таблицы, воспользуемся методом `info`:

# %%
coins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37588 entries, 0 to 37587
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             37588 non-null  object
#  1   price            37261 non-null  float64
#  2   txCount          36068 non-null  float64
#  3   txVolume         35758 non-null  float64
#  4   activeAddresses  36068 non-null  float64
#  5   symbol           37588 non-null  object
#  6   name             37588 non-null  object
#  7   open             37588 non-null  float64
#  8   high             37588 non-null  float64
#  9   low              37588 non-null  float64
#  10  close            37588 non-null  float64
#  11  volume           37588 non-null  float64
#  12  market           37588 non-null  float64
# dtypes: float64(10), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# Посмотрим простейшие статистики для числовых колонок (метод `describe`):

# %%
coins.describe()
# Out:
#               price       txCount      txVolume  activeAddresses  \
# count  37261.000000  3.606800e+04  3.575800e+04     3.606800e+04
# mean     127.395042  1.960144e+04  4.745076e+53     3.295039e+04
# std      859.109058  7.702995e+04  8.972837e+55     1.143196e+05
# min        0.000002  0.000000e+00  0.000000e+00     0.000000e+00
# 25%        0.059871  3.410000e+02  2.751161e+05     2.920000e+02
# 50%        1.020000  1.214500e+03  2.007019e+06     1.388000e+03
# 75%        8.710000  6.247000e+03  1.425408e+07     1.173400e+04
# max    19475.800000  1.349890e+06  1.696744e+58     1.283929e+06
#
#                open          high           low         close        volume  \
# count  37588.000000  37588.000000  37588.000000  37588.000000  3.758800e+04
# mean     125.652051    131.127449    119.791636    125.771519  1.302249e+08
# std      855.436562    890.527305    813.697042    855.954704  8.042239e+08
# min        0.000002      0.000003      0.000002      0.000002  0.000000e+00
# 25%        0.053032      0.057809      0.049289      0.053147  8.794400e+04
# 50%        1.000000      1.050000      1.000000      1.000000  1.949815e+06
# 75%        8.772500      9.480000      8.150000      8.810000  1.770732e+07
# max    19475.800000  20089.000000  18974.100000  19497.400000  2.384090e+10
#
#              market
# count  3.758800e+04
# mean   2.720948e+09
# std    1.534546e+10
# min    0.000000e+00
# 25%    1.356655e+07
# 50%    1.323890e+08
# 75%    5.156410e+08
# max    3.261410e+11

# %% [markdown]
# Можем выбрать отдельную колонку, обратившись к DataFrame по имени столбца:

# %%
type(coins['price'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# С колонками можно выполнять поэлементные операции:

# %%
coins['high']
# Out:
# 0        135.980000
# 1          4.400000
# 2        147.490000
# 3          4.570000
# 4        146.930000
#             ...
# 37583      0.299955
# 37584      0.039737
# 37585    240.340000
# 37586      0.133254
# 37587      1.340000
# Name: high, Length: 37588, dtype: float64

# %%
coins['low']
# Out:
# 0        132.100000
# 1          4.180000
# 2        134.000000
# 3          4.230000
# 4        134.050000
#             ...
# 37583      0.289500
# 37584      0.037680
# 37585    229.210000
# 37586      0.124194
# 37587      1.250000
# Name: low, Length: 37588, dtype: float64

# %%
coins['high'] - coins['low']
# Out:
# 0         3.880000
# 1         0.220000
# 2        13.490000
# 3         0.340000
# 4        12.880000
#            ...
# 37583     0.010455
# 37584     0.002057
# 37585    11.130000
# 37586     0.009060
# 37587     0.090000
# Length: 37588, dtype: float64

# %% [markdown]
# Можем добавить новые колонки в таблицу:

# %%
coins['spread'] = coins['high'] - coins['low']
coins.head(5)
# Out:
#          date   price  txCount      txVolume  activeAddresses symbol  \
# 0  2013-04-28  135.30  41702.0  6.879868e+07         117984.0    BTC
# 1  2013-04-28    4.30   9174.0  4.431952e+07          17216.0    LTC
# 2  2013-04-29  134.44  51602.0  1.138128e+08          86925.0    BTC
# 3  2013-04-29    4.37   9275.0  3.647810e+07          18395.0    LTC
# 4  2013-04-30  144.00  47450.0  8.426632e+07          76871.0    BTC
#
#        name    open    high     low   close  volume        market  spread
# 0   Bitcoin  135.30  135.98  132.10  134.21     0.0  1.500520e+09    3.88
# 1  Litecoin    4.30    4.40    4.18    4.35     0.0  7.377340e+07    0.22
# 2   Bitcoin  134.44  147.49  134.00  144.54     0.0  1.491160e+09   13.49
# 3  Litecoin    4.37    4.57    4.23    4.38     0.0  7.495270e+07    0.34
# 4   Bitcoin  144.00  146.93  134.05  139.00     0.0  1.597780e+09   12.88

# %% [markdown]
# Все изменения таблицы будут лишь в оперативной памяти (в переменных Python), на данные в файлах это не влияет:

# %%
coins = pd.read_csv('coins.csv')
demo_coins.columns
# Out:
# Index(['date', 'price', 'txCount', 'txVolume', 'activeAddresses', 'symbol',
#        'name', 'open', 'high', 'low', 'close', 'volume', 'market'],
#       dtype='object')

# %% [markdown]
# Можем и удалить колонки с помощью `del` или метода `pop`:

# %%
del coins['symbol']  # Можно иначе: coins.pop('spread')

# %%
coins.head()
# Out:
#          date   price  txCount      txVolume  activeAddresses      name  \
# 0  2013-04-28  135.30  41702.0  6.879868e+07         117984.0   Bitcoin
# 1  2013-04-28    4.30   9174.0  4.431952e+07          17216.0  Litecoin
# 2  2013-04-29  134.44  51602.0  1.138128e+08          86925.0   Bitcoin
# 3  2013-04-29    4.37   9275.0  3.647810e+07          18395.0  Litecoin
# 4  2013-04-30  144.00  47450.0  8.426632e+07          76871.0   Bitcoin
#
#      open    high     low   close  volume        market
# 0  135.30  135.98  132.10  134.21     0.0  1.500520e+09
# 1    4.30    4.40    4.18    4.35     0.0  7.377340e+07
# 2  134.44  147.49  134.00  144.54     0.0  1.491160e+09
# 3    4.37    4.57    4.23    4.38     0.0  7.495270e+07
# 4  144.00  146.93  134.05  139.00     0.0  1.597780e+09

# %% [markdown]
# Колонки в таблицах pandas ведут себя как массивы неизменяемой длины. Приятное отличие состоит в том, что колонки имеют много полезных для аналитики методов:

# %%
coins['symbol']
# Out:
# 0        BTC
# 1        LTC
# 2        BTC
# 3        LTC
# 4        BTC
#         ...
# 37583    XLM
# 37584    XVG
# 37585    ZEC
# 37586    ZIL
# 37587    ZRX
# Name: symbol, Length: 37588, dtype: object

# %%
type(coins['symbol'])
# Out:
# pandas.core.series.Series

# %%
help(pd.core.series.Series.value_counts)

# %%
coins['symbol'].value_counts()
# Out:
# symbol
# BTC      1866
# LTC      1866
# DOGE     1635
# VTC      1599
# DGB      1582
#          ...
# ZIL       133
# POLY      125
# CENNZ      86
# LOOM       85
# CTXC       52
# Name: count, Length: 66, dtype: int64

# %%
variable = coins['symbol'].value_counts() # Количества записей в таблице для каждой монеты

# %%
variable['ZIL']
# Out:
# 133

# %%
coins['symbol'].value_counts()['CENNZ']
# Out:
# 86

# %%
# Самая высокая цена монеты во всей таблице
coins['price'].max()
# Out:
# 19475.8

# %%
# Средняя цена монет во всей таблице
coins['price'].mean()
# Out:
# 127.39504201435274

# %% [markdown]
# Для колонок работают стандартные методы индексации списков, но есть и другие:

# %%
coins['txVolume'][:5]
# Out:
# 0    6.879868e+07
# 1    4.431952e+07
# 2    1.138128e+08
# 3    3.647810e+07
# 4    8.426632e+07
# Name: txVolume, dtype: float64

# %% [markdown]
# Для колонок определены бинарные операции и методы которые возвращают специальную колонку из булевских значений. Истина будет храниться только для тех индексов для которых выполнено условие. Рассмотрим на примере:

# %%
coins['txCount']
# Out:
# 0        41702.0
# 1         9174.0
# 2        51602.0
# 3         9275.0
# 4        47450.0
#           ...
# 37583     4830.0
# 37584     7205.0
# 37585    10687.0
# 37586     1313.0
# 37587      795.0
# Name: txCount, Length: 37588, dtype: float64

# %%
# Строки колонки для которых txCount был больше 1000
coins['txCount'] > 10000
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 37583    False
# 37584    False
# 37585     True
# 37586    False
# 37587    False
# Name: txCount, Length: 37588, dtype: bool

# %%
coins['txCount'][coins['txCount'] > 10000]
# Out:
# 0        41702.0
# 2        51602.0
# 4        47450.0
# 6        55176.0
# 8        55295.0
#           ...
# 37545    32123.0
# 37557    25346.0
# 37562    18273.0
# 37580    59491.0
# 37585    10687.0
# Name: txCount, Length: 7092, dtype: float64

# %%
coins['symbol']

# %%
# Строки в которых значение попадает в заранее заданный набор
coins['symbol'].isin(['BTC', 'ADA'])
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 37583    False
# 37584    False
# 37585    False
# 37586    False
# 37587    False
# Name: symbol, Length: 37588, dtype: bool

# %%
coins[coins['symbol'].isin(['BTC', 'ADA'])]
# Out:
#              date        price   txCount      txVolume  activeAddresses  \
# 0      2013-04-28   135.300000   41702.0  6.879868e+07         117984.0
# 2      2013-04-29   134.440000   51602.0  1.138128e+08          86925.0
# 4      2013-04-30   144.000000   47450.0  8.426632e+07          76871.0
# 6      2013-05-01   139.000000   55176.0  1.206825e+08          83564.0
# 8      2013-05-02   116.380000   55295.0  9.337533e+07          81920.0
# ...           ...          ...       ...           ...              ...
# 37385  2018-06-04  7722.530000  209733.0  7.925997e+09         702904.0
# 37448  2018-06-05     0.214247    1652.0  3.081912e+08           3682.0
# 37455  2018-06-05  7500.900000  212726.0  5.821974e+09         655694.0
# 37518  2018-06-06     0.220565    1572.0  2.439159e+08           3802.0
# 37525  2018-06-06  7625.970000  206270.0  5.055067e+09         651145.0
#
#       symbol     name         open         high          low        close  \
# 0        BTC  Bitcoin   135.300000   135.980000   132.100000   134.210000
# 2        BTC  Bitcoin   134.440000   147.490000   134.000000   144.540000
# 4        BTC  Bitcoin   144.000000   146.930000   134.050000   139.000000
# 6        BTC  Bitcoin   139.000000   139.890000   107.720000   116.990000
# 8        BTC  Bitcoin   116.380000   125.600000    92.280000   105.210000
# ...      ...      ...          ...          ...          ...          ...
# 37385    BTC  Bitcoin  7722.530000  7753.820000  7474.040000  7514.470000
# 37448    ADA  Cardano     0.214247     0.221728     0.204815     0.220467
# 37455    BTC  Bitcoin  7500.900000  7643.230000  7397.000000  7633.760000
# 37518    ADA  Cardano     0.220565     0.220862     0.210708     0.215721
# 37525    BTC  Bitcoin  7625.970000  7680.430000  7502.010000  7653.980000
#
#              volume        market
# 0      0.000000e+00  1.500520e+09
# 2      0.000000e+00  1.491160e+09
# 4      0.000000e+00  1.597780e+09
# 6      0.000000e+00  1.542820e+09
# 8      0.000000e+00  1.292190e+09
# ...             ...           ...
# 37385  4.993170e+09  1.318470e+11
# 37448  1.198460e+08  5.554790e+09
# 37455  4.961740e+09  1.280810e+11
# 37518  8.476630e+07  5.718610e+09
# 37525  4.692260e+09  1.302330e+11
#
# [2115 rows x 13 columns]

# %%
# Строки колонки в которых имя монеты содержит букву 'C'
coins['symbol'].str.contains('C')
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 37583    False
# 37584    False
# 37585     True
# 37586    False
# 37587    False
# Name: symbol, Length: 37588, dtype: bool

# %%
coins[~coins['symbol'].str.contains('C')]
# Out:
#              date     price   txCount      txVolume  activeAddresses symbol  \
# 463    2013-12-15  0.000559  128955.0  1.515206e+07         157712.0   DOGE
# 466    2013-12-16  0.000299   94694.0  2.146516e+07         127087.0   DOGE
# 469    2013-12-17  0.000207   92528.0  2.575472e+06         131166.0   DOGE
# 472    2013-12-18  0.000267   95216.0  3.789441e+06         134838.0   DOGE
# 475    2013-12-19  0.000395  192523.0  1.091923e+07         248993.0   DOGE
# ...           ...       ...       ...           ...              ...    ...
# 37582  2018-06-06  0.252141    6613.0  3.267675e+06           3231.0    XEM
# 37583  2018-06-06  0.293325    4830.0  2.312763e+05            659.0    XLM
# 37584  2018-06-06  0.039586    7205.0  4.947760e+06          18228.0    XVG
# 37586  2018-06-06  0.127555    1313.0  1.596436e+07            733.0    ZIL
# 37587  2018-06-06  1.270000     795.0  6.094435e+06            599.0    ZRX
#
#            name      open      high       low     close      volume  \
# 463    Dogecoin  0.000559  0.000904  0.000290  0.000298         0.0
# 466    Dogecoin  0.000299  0.000866  0.000150  0.000205         0.0
# 469    Dogecoin  0.000207  0.000289  0.000116  0.000269         0.0
# 472    Dogecoin  0.000267  0.000362  0.000205  0.000362         0.0
# 475    Dogecoin  0.000395  0.001520  0.000328  0.001162         0.0
# ...         ...       ...       ...       ...       ...         ...
# 37582       NEM  0.252141  0.252469  0.245758  0.250975  16446800.0
# 37583   Stellar  0.293325  0.299955  0.289500  0.298269  51165000.0
# 37584     Verge  0.039586  0.039737  0.037680  0.038797   9307450.0
# 37586   Zilliqa  0.127555  0.133254  0.124194  0.131766  54667900.0
# 37587        0x  1.270000  1.340000  1.250000  1.330000  17778000.0
#
#              market
# 463    3.488670e+06
# 466    1.970320e+06
# 469    1.526120e+06
# 472    2.160040e+06
# 475    3.487800e+06
# ...             ...
# 37582  2.269270e+09
# 37583  5.450080e+09
# 37584  5.959400e+08
# 37586  9.348810e+08
# 37587  6.741510e+08
#
# [26667 rows x 13 columns]

# %% [markdown]
# Для колонок можно составлять сложные логические выражения (скобки обязательны!):

# %%
((coins['price'] > 18000) | (coins['market'] > 200_000)) & (coins['symbol'] == 'BTC')
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 37583    False
# 37584    False
# 37585    False
# 37586    False
# 37587    False
# Length: 37588, dtype: bool

# %%
coins[((coins['price'] > 18000) | (coins['market'] > 200_000)) & (coins['symbol'] == 'BTC')]
# Out:
#              date    price   txCount      txVolume  activeAddresses symbol  \
# 0      2013-04-28   135.30   41702.0  6.879868e+07         117984.0    BTC
# 2      2013-04-29   134.44   51602.0  1.138128e+08          86925.0    BTC
# 4      2013-04-30   144.00   47450.0  8.426632e+07          76871.0    BTC
# 6      2013-05-01   139.00   55176.0  1.206825e+08          83564.0    BTC
# 8      2013-05-02   116.38   55295.0  9.337533e+07          81920.0    BTC
# ...           ...      ...       ...           ...              ...    ...
# 37245  2018-06-02  7536.72  174345.0  4.151723e+09         521910.0    BTC
# 37315  2018-06-03  7632.09  163280.0  4.477652e+09         531463.0    BTC
# 37385  2018-06-04  7722.53  209733.0  7.925997e+09         702904.0    BTC
# 37455  2018-06-05  7500.90  212726.0  5.821974e+09         655694.0    BTC
# 37525  2018-06-06  7625.97  206270.0  5.055067e+09         651145.0    BTC
#
#           name     open     high      low    close        volume        market
# 0      Bitcoin   135.30   135.98   132.10   134.21  0.000000e+00  1.500520e+09
# 2      Bitcoin   134.44   147.49   134.00   144.54  0.000000e+00  1.491160e+09
# 4      Bitcoin   144.00   146.93   134.05   139.00  0.000000e+00  1.597780e+09
# 6      Bitcoin   139.00   139.89   107.72   116.99  0.000000e+00  1.542820e+09
# 8      Bitcoin   116.38   125.60    92.28   105.21  0.000000e+00  1.292190e+09
# ...        ...      ...      ...      ...      ...           ...           ...
# 37245  Bitcoin  7536.72  7695.83  7497.26  7643.45  4.939300e+09  1.286450e+11
# 37315  Bitcoin  7632.09  7754.89  7613.04  7720.25  4.851760e+09  1.302880e+11
# 37385  Bitcoin  7722.53  7753.82  7474.04  7514.47  4.993170e+09  1.318470e+11
# 37455  Bitcoin  7500.90  7643.23  7397.00  7633.76  4.961740e+09  1.280810e+11
# 37525  Bitcoin  7625.97  7680.43  7502.01  7653.98  4.692260e+09  1.302330e+11
#
# [1866 rows x 13 columns]

# %%
money_mask = ((coins['price'] > 18000) | (coins['market'] > 200_000))
coins[money_mask & (coins['symbol'] == 'BTC')]

# %% [markdown]
# Основное назначение получающихся булевых колонок в том, что они могут быть использованы как индексирующий объект. Эдакий продвинутый slicing для колонок и таблиц.

# %%
# Выбрать из таблицы записи когда цена биткоина была меньше 100 USD
coins[(coins['price'] < 100) & (coins['symbol'] == 'BTC')]

# %%
coins['symbol'] == 'LTC'

# %%
coins['txCount']

# %%
# Количество транзакций лайткойна
seria = coins['txCount'][coins['symbol'] == 'LTC']
seria

# %% [markdown]
# **Задание**: У какой монеты была самая высокая цена?

# %%
# your code here
max_price = coins['price'].max()
max_price
# Out:
# 19475.8

# %%
max_mask = coins['price'] == max_price
max_mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37583    False
# 37584    False
# 37585    False
# 37586    False
# 37587    False
# Name: price, Length: 37588, dtype: bool

# %%
coins[max_mask]
# Out:
#              date    price   txCount      txVolume  activeAddresses symbol  \
# 25971  2017-12-17  19475.8  391725.0  3.746920e+10        1176110.0    BTC
#
#           name     open     high      low    close        volume        market
# 25971  Bitcoin  19475.8  20089.0  18974.1  19140.8  1.331460e+10  3.261410e+11

# %%
coins['name'][max_mask]
# Out:
# 25971    Bitcoin
# Name: name, dtype: object

# %%
coins['name'][max_mask].values
# Out:
# array(['Bitcoin'], dtype=object)

# %%
list(coins['name'][max_mask].values)
# Out:
# ['Bitcoin']

# %%
coins.loc[coins['name'][max_mask].index]

# %%
coins['name'][max_mask].values.tolist()

# %%
coins['name'][coins['price'] == coins['price'].max()].values.tolist()

# %%
coins['name'][coins['price'] == coins['price'].max()]
# Out:
# 25971    Bitcoin
# Name: name, dtype: object

# %% [markdown]
# Для таблиц есть индексирование, и по строкам и по колонкам:

# %%
# Выбрать из таблицы максимальную цену и объем торгов за дни когда цена DOGE была выше 1 цента
coins.loc[
    (coins['symbol'] == 'DOGE') & (coins['price'] > 0.01),
    ['high', 'volume']
]
# Out:
#            high       volume
# 27257  0.015788  283717000.0
# 27322  0.018773  288184000.0
# 27387  0.017664  235114000.0
# 27452  0.015569  115255000.0
# 27517  0.013560  100243000.0
# 27582  0.013153   62722000.0
# 27647  0.013339   56971300.0
# 27712  0.013653   55890600.0
# 27777  0.013187   65899000.0
# 27842  0.011779   62765500.0

# %% [markdown]
# **Поздравляем!** Вы научились делать простейшие выборки из данных и немного их преобразовывать.
#
# Не забывайте  использовать `help()` и tab-completion чтобы узнать больше о возможностях `pandas`.
#
# **Правило работы с `pandas`:**
#
# >Если вам очень хочется пройтись циклом по таблице и что-то сделать с данными, очень вероятно, что вы делаете что-то неправильно и, скорее всего, в pandas есть инструмент для вашей задачи.
#
# Оставшаяся часть ноутбука посвящена перечислению фич, и может показаться скучной, но не зная этих методов вы каждый раз будете переизобретать велосипед.

# %% [markdown]
# # Типы данных в pandas

# %% [markdown]
# В `pandas` есть два основных типа данных:
#
# - `pandas.Series`
# - `pandas.DataFrame`

# %% [markdown]
# ## `pandas.Series`

# %% [markdown]
# Про `pandas.Series` стоит думать как про одномерный массив фиксированного размера из данных одного типа.
#
# В отличие от массивов доступ к элементам может быть по нечисловому индексу. Индекс стоит понимать как ключи.
#
# Объекты типа `pandas.Series` очень часто используются как возвращаемые значения в `pandas`.

# %%
# pandas.Series хранящий буквы со стандартной индексацией
pd.Series(data=['BTC', 'LTC', 'DOGE', 'DASH'])
# Out:
# 0     BTC
# 1     LTC
# 2    DOGE
# 3    DASH
# dtype: object

# %%
# pandas.Series хранящий числа типа str cо специальным индексом
pd.Series(data=['BTC', 'ETH', 'XRP'],
          index=['first_coin', 'second_coin', 'third_coin'], dtype=str)
# Out:
# first_coin     BTC
# second_coin    ETH
# third_coin     XRP
# dtype: object

# %%
# pandas.Series созданный из словаря
pd.Series({'first_coin': 'BTC', 'second_coin': 'ETH', 'third_coin': 'XRP'})
# Out:
# first_coin     BTC
# second_coin    ETH
# third_coin     XRP
# dtype: object

# %%
# Стандартная индексация
sequence = pd.Series(data=['!', 'the', 'Moon', 'To'])
sequence
# Out:
# 0       !
# 1     the
# 2    Moon
# 3      To
# dtype: object

# %%
sequence[[3, 1, 2, 0, 0, 0]]  # Доступ к нескольким элементам по их позициям
# Out:
# 3      To
# 1     the
# 2    Moon
# 0       !
# 0       !
# 0       !
# dtype: object

# %%
sequence[3, 1, 2, 0, 0, 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-621a7d24e724> in <cell line: 1>()
# ----> 1 sequence[3, 1, 2, 0, 0, 0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1031             return self._get_values(key)
#    1032
# -> 1033         return self._get_with(key)
#    1034
#    1035     def _get_with(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1046             )
#    1047         elif isinstance(key, tuple):
# -> 1048             return self._get_values_tuple(key)
#    1049
#    1050         elif not is_list_like(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_values_tuple(self, key)
#    1084
#    1085         if not isinstance(self.index, MultiIndex):
# -> 1086             raise KeyError("key of type tuple not found and not a MultiIndex")
#    1087
#    1088         # If key is contained, would have returned by now
#
# KeyError: 'key of type tuple not found and not a MultiIndex'

# %%
sequence

# %%
sequence[3]  # Доступ к элементу по позиции
# Out:
# 'To'

# %%
# Спец индексация
sequence = pd.Series(data=['!', 'the', 'Moon', 'To'],
                     index=['04-11-2018', '02-11-2018', '03-11-2018', '01-11-2018'])

# %%
sequence[['01-11-2018', '02-11-2018', '03-11-2018', '04-11-2018']]  # Доступ к нескольким элементам по их индексам
# Out:
# 01-11-2018      To
# 02-11-2018     the
# 03-11-2018    Moon
# 04-11-2018       !
# dtype: object

# %%
sequence['01-11-2018']  # Доступ к элементу по индексу
# Out:
# 'To'

# %%
# Чтобы не засорять global namespace
del sequence

# %% [markdown]
# ## `pandas.DataFrame`

# %% [markdown]
# Данные типа `pandas.DataFrame` - это двумерный массив (переменного размера) разнородных данных (но однородных по колонкам).
#
# Лучше всего предстаставлять себе `pandas.DataFrame` как набор колонок, где каждая колонка это `pandas.Series`.

# %%
# Создание простейшей таблицы
pd.DataFrame(data=['BTC', 'LTC', 'XRP'])
# Out:
#      0
# 0  BTC
# 1  LTC
# 2  XRP

# %%
# Cоздание таблицы с именами колонок
pd.DataFrame(data=[['BTC', 10000],['LTC', 200],['XRP', 1]],
             columns=['symbol', 'price'])
# Out:
#   symbol  price
# 0    BTC  10000
# 1    LTC    200
# 2    XRP      1

# %%
import datetime
type(datetime.datetime.now())
# Out:
# datetime.datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2024, 7, 22, 17, 53, 14, 32703)

# %%
# Cоздание таблицы с именами колонок и указанием индекса
pd.DataFrame(
    data=[['BTC', 10000],['LTC', 200],['XRP', 1]],
    columns=['symbol', 'price'],
    # DatetimeIndex - это специальный тип данных для индексов содержащих время
    index=pd.DatetimeIndex(['01-11-2018', '03-11-2018', '23-08-2018'])
)
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1

# %%
# Создание по готовым pandas.Series
pd.DataFrame({
    'symbol': pd.Series(data=['BTC','LTC'], index=pd.DatetimeIndex(['03-11-2018', '01-11-2018'])),
    'price': pd.Series(data=[10000, 200], index=pd.DatetimeIndex(['01-11-2018', '03-11-2018']))
}).axes
# Out:
# [DatetimeIndex(['2018-01-11', '2018-03-11'], dtype='datetime64[ns]', freq=None),
#  Index(['symbol', 'price'], dtype='object')]

# %% [markdown]
# Некоторые функции в `pandas` одинаково применимы как к строкам, так и к столбцам.
#
# В этом случае, в функцию можно передать аргумент `axis`:
# - значение `0` (по умолчанию) - работа по строкам
# - значение `1` - работа по колонкам

# %% [markdown]
# # Базовые методы `pandas.Series`

# %% [markdown]
# Посмотрим на самые базовые методы класса `pandas.Series`:

# %%
sequence = pd.Series(data=['BTC', 'LTC', 'DOGE', 'DASH'], index=['leader', 'alternative', 'joke', 'bouncer'])

# %%
sequence
# Out:
# leader          BTC
# alternative     LTC
# joke           DOGE
# bouncer        DASH
# dtype: object

# %%
# Индекс наших данных
sequence.axes
# Out:
# [Index(['leader', 'alternative', 'joke', 'bouncer'], dtype='object')]

# %%
# Тип наших данных
sequence.dtype
# Out:
# dtype('O')

# %%
# Проверка на пустоту
sequence.empty
# Out:
# False

# %%
# Количество размерностей. Для pandas.Series всегда 1
sequence.ndim
# Out:
# 1

# %%
# Количество элементов
sequence.size
# Out:
# 4

# %%
# Размеры
sequence.shape
# Out:
# (4,)

# %%
# Получить данные в виде numpy массива. Низкоуровневое представление с точки зрения pandas
sequence.values
# Out:
# array(['BTC', 'LTC', 'DOGE', 'DASH'], dtype=object)

# %%
# Получить первые 3 элемента
sequence.head(3)
# Out:
# leader          BTC
# alternative     LTC
# joke           DOGE
# dtype: object

# %%
# Получить последние 2 элемента
sequence.tail(2)
# Out:
# joke       DOGE
# bouncer    DASH
# dtype: object

# %%
del sequence

# %% [markdown]
# # Базовые методы `pandas.DataFrame`

# %% [markdown]
# Класс `DataFrame` огромен.
#
# Мы рассмотрим только самые часто используемые в нем методы:

# %%
table = pd.DataFrame(
    data=[['BTC', 10000],['LTC', 200],['XRP', 1]],
    columns=['symbol', 'price'],
    # DatetimeIndex - это специальный тип данных для индексов содержащих время
    index=pd.DatetimeIndex(['01-11-2018', '03-11-2018', '23-08-2018'])
)
table
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1

# %%
# Транспонировать таблицу
table.T
# Out:
#        2018-01-11 2018-03-11 2018-08-23
# symbol        BTC        LTC        XRP
# price       10000        200          1

# %%
# Получить индексы срок и столбцов
table.axes
# Out:
# [DatetimeIndex(['2018-01-11', '2018-03-11', '2018-08-23'], dtype='datetime64[ns]', freq=None),
#  Index(['symbol', 'price'], dtype='object')]

# %%
# Получить типы данных в колонках
table.dtypes
# Out:
# symbol    object
# price      int64
# dtype: object

# %%
# Проверка на пустоту
table.empty
# Out:
# False

# %%
pd.DataFrame().empty
# Out:
# True

# %%
# Размеры
table.shape
# Out:
# (3, 2)

# %%
# Количество элементов
table.size
# Out:
# 6

# %%
# Низкоуровневое представление таблицы
table.values
# Out:
# array([['BTC', 10000],
#        ['LTC', 200],
#        ['XRP', 1]], dtype=object)

# %%
# Получить первые 3 строки
table.head(3)
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1

# %%
# Получить последние 2 строки
table.tail(2)
# Out:
#            symbol  price
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1

# %%
del table

# %% [markdown]
# # Работа со строками и столбцами

# %% [markdown]
# Обращаться к строкам таблицы можно по номеру или по индексу

# %%
import pandas as pd

# %%
table = pd.DataFrame(
    data=[['BTC', 10000],['LTC', 200],['XRP', 1],['XRP', 1], ['BTC', 9000]],
    columns=['symbol', 'price'],
    # DatetimeIndex - это специальный тип данных для индексов содержащих время
    index=pd.DatetimeIndex(['01-11-2018', '03-11-2018', '03-11-2018', '23-08-2018', '02-11-2018'])
)
table
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-03-11    XRP      1
# 2018-08-23    XRP      1
# 2018-02-11    BTC   9000

# %%
series = table['symbol']
series
# Out:
# 2018-01-11    BTC
# 2018-03-11    LTC
# 2018-03-11    XRP
# 2018-08-23    XRP
# 2018-02-11    BTC
# Name: symbol, dtype: object

# %% [markdown]
# ## Доступ к отдельным строкам

# %% [markdown]
# Pandas предоставляет огромное количество способов получения желаемых элементов (см. [документацию](https://pandas.pydata.org/docs/user_guide/indexing.html)). Поэтому мы пройдемся лишь по основам.

# %% [markdown]
# ### Выбор одного элемента

# %%
table
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-03-11    XRP      1
# 2018-08-23    XRP      1
# 2018-02-11    BTC   9000

# %% [markdown]
# #### Метод iloc

# %% [markdown]
# Обращение по порядковому номеру строки:

# %%
table.iloc[1]
# Out:
# symbol    LTC
# price     200
# Name: 2018-03-11 00:00:00, dtype: object

# %%
table.iloc[1, 0]
# Out:
# 'LTC'

# %%
series.iloc[1]

# %% [markdown]
# #### Метод loc

# %% [markdown]
# Обращение по конкретному индексу:

# %%
table.loc[pd.Timestamp('01-11-2018')]
# Out:
# symbol      BTC
# price     10000
# Name: 2018-01-11 00:00:00, dtype: object

# %%
table.loc[pd.Timestamp('01-11-2018'), 'xxx']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xxx'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-0107145b4598> in <cell line: 1>()
# ----> 1 table.loc[pd.Timestamp('01-11-2018'), 'xxx']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1095             if self._is_scalar_access(key):
#    1096                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097             return self._getitem_tuple(key)
#    1098         else:
#    1099             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1278         with suppress(IndexingError):
#    1279             tup = self._expand_ellipsis(tup)
# -> 1280             return self._getitem_lowerdim(tup)
#    1281
#    1282         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1022                     return section
#    1023                 # This is an elided recursive call to iloc/loc
# -> 1024                 return getattr(section, self.name)[new_key]
#    1025
#    1026         raise IndexingError("not applicable")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1341         # fall thru to straight lookup
#    1342         self._validate_key(key, axis)
# -> 1343         return self._get_label(key, axis=axis)
#    1344
#    1345     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1291     def _get_label(self, label, axis: AxisInt):
#    1292         # GH#5567 this will fail if the label is not present in the axis.
# -> 1293         return self.obj.xs(label, axis=axis)
#    1294
#    1295     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4093                     new_index = index[loc]
#    4094         else:
# -> 4095             loc = index.get_loc(key)
#    4096
#    4097             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'xxx'

# %%
series.loc[pd.Timestamp('01-11-2018')]

# %% [markdown]
# ### Срезы

# %%
table

# %%
series

# %% [markdown]
# #### `[]`

# %% [markdown]
# `[]` с Series - как с одномерным массивом:

# %%
series[:3]
# Out:
# 2018-01-11    BTC
# 2018-03-11    LTC
# 2018-03-11    XRP
# Name: symbol, dtype: object

# %% [markdown]
# `[]` с DataFrame - срезы по строкам:

# %%
table[:3]
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-03-11    XRP      1

# %% [markdown]
# #### Метод `iloc`

# %% [markdown]
# `iloc` с Series - как с NumPy-массивами:

# %%
series.iloc[:3]
# Out:
# 2018-01-11    BTC
# 2018-03-11    LTC
# 2018-03-11    XRP
# Name: symbol, dtype: object

# %%
series.iloc[[2, 0, 1]]
# Out:
# 2018-03-11    XRP
# 2018-01-11    BTC
# 2018-03-11    LTC
# Name: symbol, dtype: object

# %% [markdown]
# `iloc` с DataFrame - как с двумерным массивом:

# %%
table.iloc[:3]

# %%
table.iloc[:3, :]

# %%
table.iloc[:3, :1]

# %% [markdown]
# #### Метод `loc`

# %%
table

# %% [markdown]
# Срезы с методом loc немного сложнее. Возможны следующие ситуации:

# %% [markdown]
# - оба элемента (начальный и конечный) присутствуют, тогда получаем все элементы между ними (включая оба элемента):

# %%
table.loc[pd.Timestamp('2018-01-11'):pd.Timestamp('2018-08-23')]

# %% [markdown]
# - отсутствует как минимум один из элементов И индекс отсортирован и сравним со начальным и конечным элементами, тогда получаем все элементы по значению между границами:

# %%
table.sort_index()

# %%
table.sort_index().loc[pd.Timestamp('2018-01-10'):pd.Timestamp('2018-03-12')]

# %% [markdown]
# - отсутствует как минимум один из элементов И индекс НЕ ОТСОРТИРОВАН и сравним со начальным и конечным элементами, тогда получаем ошибку:

# %%
table

# %%
table.loc[pd.Timestamp('2018-01-10'):pd.Timestamp('2018-03-12')]

# %% [markdown]
# ## Добавление, удаление, переименование колонок и строк

# %%
table = pd.DataFrame(
    data=[['BTC', 10000],['LTC', 200],['XRP', 1], ['BTC', 9000]],
    columns=['symbol', 'price'],
    # DatetimeIndex - это специальный тип данных для индексов содержащих время
    index=pd.DatetimeIndex(['01-11-2018', '03-11-2018', '23-08-2018', '02-11-2018'])
)
table
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1
# 2018-02-11    BTC   9000

# %%
# Удаление строк по их индексам. Можно использовать для удаления колонок, указав axis=1
# Посмотрите еще методы drop_duplicates and dropna
table.drop([pd.Timestamp('2018-08-23'), pd.Timestamp('2018-01-11')])
# Out:
#            symbol  price
# 2018-03-11    LTC    200
# 2018-02-11    BTC   9000

# %%
table
# Out:
#            symbol  price
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1
# 2018-02-11    BTC   9000

# %%
new_table = table.drop([pd.Timestamp('2018-08-23'), pd.Timestamp('2018-01-11')])
del new_table["price"]
#table.drop(..., inplace=True)

# %%
new_table

# %%
# Чтобы добавить новую колонку достаточно присвоить ей значение
table['volume'] = [2e9, 1e6, 1e4, 1e-3]  #
table

# %%
table['new_volume'] = [1e9, 1e6, 1e4]
table

# %%
# Удалять колонки очень просто
del table['volume']

# %%
table

# %%
# Переименовывание колонок
table.rename(columns={'symbol': 'Symbol', 'price': 'Price'}, inplace=True)
# table = table.rename(columns={'symbol': 'Symbol', 'price': 'Price'})

# %%
table

# %%
id(table)

# %%
id(new_table.copy())

# %%
new_table = table.copy()
new_table['new'] = ['1','2', '3', '4']
table

# %%
new_table

# %% [markdown]
# ## Итерирование

# %% [markdown]
# Итерироваться по таблице можно разными способами, но обычно так не стоит делать и лучше написать решение в виде манипуляций над столбцами/колонками

# %%
# По колонкам
for column in table:
    print(column, type(column))
# Out:
# symbol <class 'str'>
# price <class 'str'>

# %%
# По колонкам как по словарю. Значения в "словаре" это pandas.Series
for column, series in table.items():
    print(column)
    print(series)
    print('___________')
# Out:
# symbol
# 2018-01-11    BTC
# 2018-03-11    LTC
# 2018-08-23    XRP
# 2018-02-11    BTC
# Name: symbol, dtype: object
# ___________
# price
# 2018-01-11    10000
# 2018-03-11      200
# 2018-08-23        1
# 2018-02-11     9000
# Name: price, dtype: int64
# ___________

# %%
table

# %%
# По строкам как по словарю. Значения в "словаре" это pandas.Series
for index, row in table.iterrows():
    print(index)
    print(row)
    print('___________')
# Out:
# 2018-01-11 00:00:00
# symbol      BTC
# price     10000
# Name: 2018-01-11 00:00:00, dtype: object
# ___________
# 2018-03-11 00:00:00
# symbol    LTC
# price     200
# Name: 2018-03-11 00:00:00, dtype: object
# ___________
# 2018-08-23 00:00:00
# symbol    XRP
# price       1
# Name: 2018-08-23 00:00:00, dtype: object
# ___________
# 2018-02-11 00:00:00
# symbol     BTC
# price     9000
# Name: 2018-02-11 00:00:00, dtype: object
# ___________

# %% [markdown]
# ## Сортировка

# %% [markdown]
# Строки и столбцы таблицы можно сортировать. Результат сортирующих методов возвращает новую таблицу!

# %%
# Отсортировать строки по индексу по убыванию
table.sort_index(ascending=False)
# Out:
#            symbol  price
# 2018-08-23    XRP      1
# 2018-03-11    LTC    200
# 2018-02-11    BTC   9000
# 2018-01-11    BTC  10000

# %%
table

# %%
# Отсортировать колонки по возрастанию
table.sort_index(axis=1, ascending=True)
# Out:
#             price symbol
# 2018-01-11  10000    BTC
# 2018-03-11    200    LTC
# 2018-08-23      1    XRP
# 2018-02-11   9000    BTC

# %%
# Отсортировать таблицу алгоритмом quicksort по названию, а если значения равны то по цене
table.sort_values(by=['symbol', 'price'], kind='quicksort')
# Out:
#            symbol  price
# 2018-02-11    BTC   9000
# 2018-01-11    BTC  10000
# 2018-03-11    LTC    200
# 2018-08-23    XRP      1

# %%
table.sort_values?

# %%
del table, index, row, column, series

# %% [markdown]
# # Статистические функции

# %% [markdown]
# Посмотрим как pandas позволяет вычислять простейшие статистики для датасетов. Методы которые мы перечислим ниже имеют аргумет axis, который указывает вдоль какой оси надо вычислять статистику. Обычно, по-умолчанию axis=0, что соответсвует вычислениям по строкам. Если в данных есть пропуски, то они не учитываются при вычислении статистик!

# %%
earnings = pd.DataFrame(
    data=[[7629.39, -9357.49, -1661.3, 8597.23],
          [560.68, None, 10.46, 3578.5],
          [487.38, 7560.38, 1090.87, -5164.93],
          [560.68, 7560.38, None, -5164.93]],
    columns=['BTC', 'DOGE', 'ADA', 'ETH'],
    index=['yesterday', 'today', 'tomorrow','aftertomorrow']
)

# %%
earnings
# Out:
#                    BTC     DOGE      ADA      ETH
# yesterday      7629.39 -9357.49 -1661.30  8597.23
# today           560.68      NaN    10.46  3578.50
# tomorrow        487.38  7560.38  1090.87 -5164.93
# aftertomorrow   560.68  7560.38      NaN -5164.93

# %%
type(earnings['DOGE'].iloc[0])
# Out:
# numpy.float64

# %%
# Количество не None записей для каждой монеты
earnings.count()
# Out:
# BTC     4
# DOGE    3
# ADA     3
# ETH     4
# dtype: int64

# %%
earnings

# %%
# Заработки по дням
earnings.sum(axis=1)

# %%
earnings.sum()

# %%
# Средний заработок по каждой монете
earnings.mean(axis=1)

# %%
# Медианный заработок по каждой монете
earnings.median()

# %%
earnings

# %%
# Моды заработка по каждой монете
earnings.mode()

# %%
# "Разброс" заработка по каждой монете
earnings.std()

# %% [markdown]
# ![std](https://wikimedia.org/api/rest_v1/media/math/render/svg/15619dfbb9a470d310c1bc08fb61d4fb1187d057)

# %%
# 25, 50 и 75 квантиль заработка по каждой монете
earnings.quantile(q=(0.25, 0.5, 0.75, 0.9))

# %%
# Минимальный заработок по каждой монете
earnings.min()

# %%
# Максимальный заработок по каждой монете
earnings.max(axis=1)

# %%
# Абсолюты заработков по каждой монете
earnings.abs()

# %%
# Произвдение заработков по каждой монете. Да, это бессмысленно
earnings.prod()

# %%
# Кумулятивные произведения заработков по каждой монете
earnings.cumprod()
# Out:
#                         BTC          DOGE           ADA           ETH
# yesterday      7.629390e+03 -9.357490e+03 -1.661300e+03  8.597230e+03
# today          4.277646e+06           NaN -1.737720e+04  3.076519e+07
# tomorrow       2.084839e+09 -7.074618e+07 -1.895626e+07 -1.589000e+11
# aftertomorrow  1.168928e+12 -5.348680e+11           NaN  8.207076e+14

# %%
earnings
# Out:
#                    BTC     DOGE      ADA      ETH
# yesterday      7629.39 -9357.49 -1661.30  8597.23
# today           560.68      NaN    10.46  3578.50
# tomorrow        487.38  7560.38  1090.87 -5164.93
# aftertomorrow   560.68  7560.38      NaN -5164.93

# %%
# Кумулятивные суммы заработков по каждой монете
earnings.cumsum()
# Out:
#                    BTC     DOGE      ADA       ETH
# yesterday      7629.39 -9357.49 -1661.30   8597.23
# today          8190.07      NaN -1650.84  12175.73
# tomorrow       8677.45 -1797.11  -559.97   7010.80
# aftertomorrow  9238.13  5763.27      NaN   1845.87

# %%
earnings

# %%
# Процентное изменение заработка по сравнению с предыдущим значением
earnings.pct_change()

# %%
earnings.pct_change?

# %%
# Ковариация между заработком по BTC и по DOGE
earnings['BTC'].cov(earnings['DOGE'])

# %%
# Корреляция между заработком по BTC и по DOGE
earnings['BTC'].corr(earnings['DOGE'])

# %%
earnings.corr?

# %% [markdown]
# Иногда хочется посмотреть все статистики сразу. Для этого есть метод describe

# %%
earnings.describe()

# %%
del earnings

# %% [markdown]
# # Применение пользовательских функций

# %% [markdown]
# Иногда хочется применить к датасету или одной его колонке функцию. Применять можно ко всей таблице, поэлементно, поколоночно или построчно

# %%
import pandas as pd

# %%
earnings = pd.DataFrame(
    data=[[7629.39, -9357.49, -1661.3, 8597.23],
          [560.68, None, 10.46, 3578.5],
          [487.38, 7560.38, 1090.87, -5164.93]],
    columns=['BTC', 'DOGE', 'ADA', 'ETH'],
    index=['yesterday', 'today', 'tomorrow']
)
earnings
# Out:
#                BTC     DOGE      ADA      ETH
# yesterday  7629.39 -9357.49 -1661.30  8597.23
# today       560.68      NaN    10.46  3578.50
# tomorrow    487.38  7560.38  1090.87 -5164.93

# %% [markdown]
# Для  применения построчно/поколоночно используйте функцию apply. Если хочется применить построчно добавьте axis=1

# %%
#  Посчитать дисперсию заработка для каждой монеты. В лямбду приходит pandas.Series объект каждой колонки
earnings['new_stat'] = earnings.apply(lambda money: money.std() ** 2, axis=1)

# %%
earnings
# Out:
#                BTC     DOGE      ADA      ETH      new_stat
# yesterday  7629.39 -9357.49 -1661.30  8597.23  7.188737e+07
# today       560.68      NaN    10.46  3578.50  3.690148e+06
# tomorrow    487.38  7560.38  1090.87 -5164.93  2.710527e+07

# %% [markdown]
# Для поэлементного применения используйте функцию applymap

# %%
earnings

# %%
# Сделаем вид, что потери превратились в профит
earnings.applymap(abs)

# %%
earnings

# %%
earnings = earnings.applymap(abs)
earnings.applymap(abs, inplace=True) # error

# %%
earnings.applymap?

# %%
# Применять функцию можно и к отдельной колонке. В лямбду приходит отдельное значение колонки
earnings['BTC+100500'] = earnings['BTC'].apply(lambda money: money + 100500)
earnings

# %%
earnings.apply(lambda money: money.std() ** 2)

# %%
# Если нужно взаимодействие между колонками - применяйте apply row-wise (по строкам)
earnings['BTC'] = earnings.apply(lambda x: x['BTC'] + x.DOGE, axis = 1)
earnings

# %%
earnings['DOGE_PLUS'] = earnings.DOGE + earnings.ADA
earnings

# %%
earnings['DOGE PLUS'] = earnings.DOGE + earnings.ADA

# %%
earnings.DOGE PLUS

# %% [markdown]
# **Примечание:** Не забудьте самостоятельно посмотреть метод pipe

# %%
earnings.pipe?

# %%
del earnings

# %% [markdown]
# ## Работа со строковыми колонками

# %% [markdown]
# На данный момент для работы со строковыми колонками нам пришлось бы постоянно использовать метод apply. Это неудобно и поэтому в pandas сделали удобный инструмент для манипуляций со строками

# %%
taxonomy = pd.DataFrame(
    data=[['BTC', 'Bitcoin'],['LTC', 'Litecoin'], ['ETC', 'Etherium'], ['DOGE', 'Doge coin']],
    columns=['symbol', 'name']
)
taxonomy
# Out:
#   symbol       name
# 0    BTC    Bitcoin
# 1    LTC   Litecoin
# 2    ETC   Etherium
# 3   DOGE  Doge coin

# %% [markdown]
# Чтобы применять строковые функции к колонке надо обратиться к свойству .str.

# %%
# Привести все к нижнему регистру
taxonomy['symbol'].str.lower()

# %%
# Привести все к верхнему регистру
taxonomy['name'].str.upper()

# %%
taxonomy

# %%
# Длины строк
taxonomy['symbol'].str.len()

# %%
# Убрать по краям пробельные символы
taxonomy['name'].str.strip()

# %%
# Разбить строки по заданному символу
taxonomy['name'].str.split(' ')

# %%
# Склеить все строки в одну. Аналог str.join
taxonomy['symbol'].str.cat(sep=' $$$ ')

# %%
taxonomy

# %%
# Найти везде подстроку
taxonomy['name'].str.contains('coin')

# %%
~taxonomy['name'].str.contains('coin')

# %%
taxonomy[~taxonomy['name'].str.contains('coin')]

# %%
# Везде заменить строку на другую
taxonomy['name'].str.replace('coin', 'dough')

# %%
taxonomy['name'].str.replace?

# %%
# Повторить каждую строку указанное число раз
taxonomy['symbol'].str.repeat(2)
#taxonomy['symbol'].str.repeat(-3)

# %%
taxonomy

# %%
# Посчитать все появления указанной подстроки
taxonomy['name'].str.lower().str.count('e')

# %%
# Проверка наличия префикса
taxonomy['symbol'].str.startswith('B')

# %%
# Проверка наличия суффикса
taxonomy['symbol'].str.endswith('TC')

# %%
# Найти место в строках где начинается искомая строка.
taxonomy['name'].str.find('coin')

# %%
# Проверка верхнего регистра
taxonomy['symbol'].str.isupper()

# %%
# Проверка нижнего регистра
taxonomy['symbol'].str.islower()

# %%
# Проверка что все символы - цифры
taxonomy['name'].str.isnumeric()

# %%
#Посмотреть все возможные проверки
help(taxonomy['name'].str.isnumeric)

# %% [markdown]
# # Агрегации, трансформации и фильтрации

# %% [markdown]
# ## Скользящие окна

# %% [markdown]
# Мы начнем со специального случая аггрегаций данных - оконных функций. Мы поговорим о методах rolling и emw. Самостоятельно посмотрите что делает expanding.

# %%
import pandas as pd

# %%
price = pd.DataFrame(
    data=[
        [0.547, 0.745],
        [0.5, 0.964],
        [0.77, 0.718],
        [0.135, 0.845],
        [0.53, None],
        [0.15, 0.795]],
    columns=['ADA', 'DOGE'],
    # Создаем специальный индекс из 6 дней начиная с 2018-11-01
    index=pd.date_range('2018-11-01', periods=6)
)
price
# Out:
#               ADA   DOGE
# 2018-11-01  0.547  0.745
# 2018-11-02  0.500  0.964
# 2018-11-03  0.770  0.718
# 2018-11-04  0.135  0.845
# 2018-11-05  0.530    NaN
# 2018-11-06  0.150  0.795

# %%
print(price.loc[['2018-11-05','2018-11-06']])

# %% [markdown]
# Если вы хотите посчитать какую-нибудь статистическую функци (sum, mean, median, std) в скользящем окне. То есть методы rolling (обычное окно) и ewm (окно с экспоненциальным сглаживанием). Они возвращают специальные объекты которые могут аггрегировать используя стандартную или пользователскую функцию.

# %%
price.rolling(window=2)
# Out:
# Rolling [window=2,center=False,axis=0,method=single]

# %%
# Найти скользящее стандартное отклонение
price.rolling(window=2).sum()
# Out:
#               ADA   DOGE
# 2018-11-01    NaN    NaN
# 2018-11-02  1.047  1.709
# 2018-11-03  1.270  1.682
# 2018-11-04  0.905  1.563
# 2018-11-05  0.665    NaN
# 2018-11-06  0.680    NaN

# %%
price[['ADA']].rolling(window=3).mean()

# %%
# Сделать агрегацию c пользовательской функцией
price.rolling(window=4).agg(lambda series: sum(series ** 2))

# %%
# Сделать агрегацию по имени функции
price.rolling(window=2).agg('max')

# %% [markdown]
# **Примечание:** non-maximal supression

# %%
# Сделать несколько агрегаций
price.rolling(window=2).agg(['mean', sum, lambda series: max(series ** 2)])

# %%
new_price = price.rolling(window=2).agg(['mean', sum, lambda series: max(series ** 2)])
type(new_price)

# %%
price

# %%
# Сделать несколько агрегаций (для каждой колонки свои)
price.rolling(window=3).agg({'ADA': [sum, max], 'DOGE': lambda series: max(series ** 2)})

# %% [markdown]
# Объект ewm работает аналогично rolling с тем лишь отличием, что он назначает веса. Числам $x_0,\ldots,x_t$ будут назначены веса $(1-\alpha)^t, (1-\alpha)^{t-1}, \ldots, 1$, где $\alpha$ - параметр сглаживания. Например, экспоненциальное скользящее среднее будет вычисляться по формуле
# $$
# ewm_{\alpha}(x)=\frac{\sum_{i=0}^t (1-\alpha)^{t-i} x_i}{\sum_{i=0}^t(1-\alpha)^i}
# $$
#
#
# Если указать **adjust=False**, подсчёт будет идти рекурсивно: ```mean[i] = (1-alpha)*mean[i-1] + alpha*x[i]```

# %%
price

# %%
# Скользящее среднее cо сглаживанием alpha
price.ewm(alpha=0.1, adjust=True).mean()

# %%
price.ewm(alpha=0.9, adjust=True).mean()

# %%
price.ewm(alpha=0.5, adjust=True).mean()

# %%
price.ewm(alpha=0.5, adjust=False).mean()

# %%
del price

# %% [markdown]
# ## Работа с группами

# %% [markdown]
# Иногда хочется разбить данные по группам и посчитать статистики / преобразовать / пофильтровать. Для этого есть метод **groupby**. Он возвращает специальный объект для работы со сгруппированными данными.

# %%
operations = pd.DataFrame(
    data=[
        ['DOGE', 'buy', 5000, 0.2],
        ['BTC', 'buy', 10, 6000],
        ['BTC', 'buy', 2.5, 5900],
        ['DOGE', 'sell', 3000, 0.1],
        ['BTC', 'sell', 4, 6200],
        ['ETH', 'sell', 10, 400],
        ['BTC', 'buy', 1, 5600],
        ['ETH', 'buy', 20, 350],
        ['ETH', 'sell', 10, 300],
        ['DOGE', 'sell', 3000, 0.15]
    ],
    columns=['symbol', 'type', 'amount', 'price'],
    index=pd.date_range('2018-01-01', periods=10)
)
operations

# %%
# Сгруппировать операции по типу монеты
link = operations.groupby('symbol')

# %%
link

# %%
# Сгруппировать операции по типу монеты и типу операции
operations.groupby(['symbol', 'type'])

# %%
# Получить индексы строк каждой группы
operations.groupby(['symbol', 'type']).groups[('BTC', 'buy')]

# %%
# Посмотреть на содержимое каждой группы
for name, group in operations.groupby(['symbol', 'type']):
    print(name)
    print(group)

# %%
# Получить группу
operations.groupby(['symbol', 'type']).get_group(('BTC', 'buy'))

# %% [markdown]
# Теперь посмотрим как агрегировать данные для каждой группы

# %%
# Найти обороты для каждой монеты и операции
grouper = operations.groupby(['symbol', 'type'])
#grouper['amount'].agg('mean')
grouper['amount'].mean()

# Есть ещё полезный метод operations.groupby(...).transform(func) - предлагается разобрать самостоятельно

# %%
# Найти обороты и самые крупные сделки для каждой монеты и операции
grouper = operations.groupby(['symbol', 'type'])
grouper['amount'].agg([sum, max])

# %%
# Найти обороты и среднюю цену для каждой монеты и операции
grouper = operations.groupby(['symbol', 'type'])
grouper.agg({'amount': sum, 'price': ['mean', 'median']})

# %%
grouper.agg({'amount': sum, 'price': pd.DataFrame.mean})

# %%
type(grouper)

# %%
help(pd.core.groupby.generic.DataFrameGroupBy)

# %%
help(operations.groupby)

# %%
# Получить размер группы в которой сидит запись
operations.groupby(['symbol', 'type']).apply(lambda series: series.shape[0])

# %%
#Вывести группы по убыванию числа уникальных значений в колонке amount
operations.groupby(['symbol', 'type'])['amount'].nunique()

# %%
operations

# %% [markdown]
# Сгруппированные данные можно фильтровать. Вы можете решить какие группы оставить с помощью вашей функции. Она на вход принимает pandas.DataFrame и возвращает bool

# %%
help(operations.groupby(['symbol', 'type']).filter)

# %%
# Выбрать монеты и операции для которых оборот был больше 20 монет
operations.groupby(['symbol', 'type']).filter(lambda table: table['amount'].sum() >= 20)

# %%
del operations, name, group

# %% [markdown]
# ## Сводные таблицы

# %% [markdown]
# Большинство таблиц в сыром виде похожи на логи где каждая строка это запись. Никакой оргинизации в данных в этих таблицах нет, а хотелось бы. Для этого в pandas существуют сводные таблицы.

# %%
operations = pd.DataFrame(
    data=[
        ['DOGE', 'buy', 5000, 0.2, 'Joe Doe', 'success'],
        ['BTC', 'buy', 10, 6000, 'Elon Musk', 'error'],
        ['BTC', 'buy', 2.5, 5900, 'George Bush', 'success'],
        ['DOGE', 'sell', 3000, 0.1, 'John Romero', 'success'],
        ['BTC', 'sell', 4, 6200, 'Jack Ma', 'success'],
        ['ETH', 'sell', 10, 400, 'Satoshi Nakomoto', 'error'],
        ['BTC', 'buy', 1, 5600, 'Vladimir Vladimirovich', 'success'],
        ['ETH', 'buy', 20, 350, 'George Bush', 'success'],
        ['ETH', 'sell', 10, 300, 'Jack Ma', 'error'],
        ['DOGE', 'sell', 3000, 0.15, 'Joe Doe', 'success']
    ],
    columns=['symbol', 'type', 'amount', 'price', 'user', 'status'],
    index=pd.date_range('2018-01-01', periods=10)
)
operations

# %% [markdown]
# Лучше всего понять как они работают это разобрать пример. Найдем сколько суммарно  было куплено и продано каждого типа монет. В результирующей сводной таблице индексом будет название монеты, колонки - типы транзакций (т.е. покупки или продажи). В самих ячейках будет суммарное количество монет.

# %%
operations.pivot_table(
    values='amount',
    index='symbol',
    columns='type',
    aggfunc='sum'
)

# %% [markdown]
# Если не указывать явно аргумент aggfunc, то агрегация будет через усреднение (а не через суммирование как было в нашем примере). Расмотрим более сложный пример.

# %%
operations.pivot_table(
    values='amount',
    index=['user', 'symbol'],  # Индекс может быть иерархическим и строиться по нескольким колонкам
    columns=['type', 'status'],  # Аналогично иерархическими могут быть и колонки
    aggfunc=['sum', 'mean']  # Можно вычислять сразу несколько агрегаций
)

# %% [markdown]
# И самый монструозный пример, где мы сделаем сводную таблиц для цен и объемов торгов.

# %%
operations.pivot_table(
    values=['amount', 'price'],  # Можно находить статистику по разным числовым показателям
    index=['symbol', 'user'],
    columns=['type', 'status'],
    aggfunc={
        'amount': ['sum', 'mean'],
        'price': 'max'}  # Тогда для каждого показателя надо указать какие агрегации вы хотите
)

# %% [markdown]
# Для построения сводных таблиц в pandas есть более простая функция. pandas.pivot. Она не делает никаких агрегаций, поэтому при ее использовании вы должны быть уверены, что на каждую ячейку результирующей сводной таблицы придется только одно значение показателя из исходной таблицы. В противном случае будет ошибка. Можете попробовать построить сводную таблицу
# ```
# operations.pivot(values='amount', index='user', columns='user')
# ```
# чтобы убедиться.

# %%
del operations

# %% [markdown]
# **Задание:** Самостоятельно разберитесь с функциями pandas.stack, pandas.unstack и pandas.melt. Вам поможет [этот tutorial](https://pandas.pydata.org/pandas-docs/stable/reshaping.html)

# %% [markdown]
# # Пропуски и ошибки в данных

# %% [markdown]
# В реальной жизни данные с которыми надо работать содержат пропуски или просто неверные значения. Мы обсудим как это можно исправить

# %%
price = pd.DataFrame(
    data=[
        [0.547, 0.745],
        [-2, -1],
        [None, 0.718],
        [0.135, 0.845],
        [0.53, None],
        [None, -1]],
    columns=['ADA', 'DOGE'],
    # Создаем специальный индекс из 6 дней начиная с 2018-11-01
    index=pd.date_range('2018-11-01', periods=6)
)
price
# Out:
#               ADA   DOGE
# 2018-11-01  0.547  0.745
# 2018-11-02 -2.000 -1.000
# 2018-11-03    NaN  0.718
# 2018-11-04  0.135  0.845
# 2018-11-05  0.530    NaN
# 2018-11-06    NaN -1.000

# %%
# Найти места где есть пропуски методом isnull. Аналогично есть метод notnull
price.isnull()
# Out:
#               ADA   DOGE
# 2018-11-01  False  False
# 2018-11-02  False  False
# 2018-11-03   True  False
# 2018-11-04  False  False
# 2018-11-05  False   True
# 2018-11-06   True  False

# %%
price.info()

# %%
# Заполнить все пропуски дефолтным занчением
price.fillna(0)
# Out:
#               ADA   DOGE
# 2018-11-01  0.547  0.745
# 2018-11-02 -2.000 -1.000
# 2018-11-03  0.000  0.718
# 2018-11-04  0.135  0.845
# 2018-11-05  0.530  0.000
# 2018-11-06  0.000 -1.000

# %%
price
# Out:
#               ADA   DOGE
# 2018-11-01  0.547  0.745
# 2018-11-02 -2.000 -1.000
# 2018-11-03    NaN  0.718
# 2018-11-04  0.135  0.845
# 2018-11-05  0.530    NaN
# 2018-11-06    NaN -1.000

# %%
# Заполнить все пропуски занчениями со cледующей строки
price.fillna(method='bfill')

# %%
# Заполнить все пропуски занчениями с предыдущей строки
price.fillna(method='ffill')

# %%
help(pd.DataFrame.fillna)

# %%
price

# %%
#  Выкинуть строки содержащие nan'ы
price.dropna()
# Out:
#               ADA   DOGE
# 2018-11-01  0.547  0.745
# 2018-11-02 -2.000 -1.000
# 2018-11-04  0.135  0.845

# %%
help(pd.DataFrame.dropna)

# %%
#  Выкинуть колонки содержащие nan'ы
price.dropna(axis=1).empty

# %%
price

# %%
# Подменить значения
price.replace({-1: 0, -2: 0})

# %%
help(pd.DataFrame.replace)

# %%
price

# %%
del price

# %% [markdown]
# # Слияния и конкатенации таблиц

# %% [markdown]
# Если у вас есть две таблицы, то информацию в них можно объединить двумя способами: конкатенация ("прилепить снизу новую таблицу") и объединение (найти объединение записей таблиц если у них хранятся одни и те же значения в выбранных колонках).

# %%
operations_old = pd.DataFrame(
    data=[
        ['DOGE', 'buy', 5000, 0.2],
        ['BTC', 'buy', 10, 6000],
        ['BTC', 'buy', 2.5, 5900],
        ['DOGE', 'sell', 3000, 0.1],
        ['BTC', 'sell', 4, 6200],
    ],
    columns=['symbol', 'type', 'amount', 'price']
)
operations_old
# Out:
#   symbol  type  amount   price
# 0   DOGE   buy  5000.0     0.2
# 1    BTC   buy    10.0  6000.0
# 2    BTC   buy     2.5  5900.0
# 3   DOGE  sell  3000.0     0.1
# 4    BTC  sell     4.0  6200.0

# %%
operations_new = pd.DataFrame(
    data=[
        ['ETH', 'sell', 10, 400],
        ['BTC', 'buy', 1, 5600],
        ['ETH', 'buy', 20, 350],
        ['ETH', 'sell', 10, 300],
        ['DOGE', 'sell', 3000, 0.15]
    ],
    columns=['symbol', 'type', 'amount', 'price']
)
operations_new
# Out:
#   symbol  type  amount    price
# 0    ETH  sell      10   400.00
# 1    BTC   buy       1  5600.00
# 2    ETH   buy      20   350.00
# 3    ETH  sell      10   300.00
# 4   DOGE  sell    3000     0.15

# %%
#  Сконкатенировать таблицы в указанном порядке
new_df = pd.concat([operations_old, operations_new])
new_df
# Out:
#   symbol  type  amount    price
# 0   DOGE   buy  5000.0     0.20
# 1    BTC   buy    10.0  6000.00
# 2    BTC   buy     2.5  5900.00
# 3   DOGE  sell  3000.0     0.10
# 4    BTC  sell     4.0  6200.00
# 0    ETH  sell    10.0   400.00
# 1    BTC   buy     1.0  5600.00
# 2    ETH   buy    20.0   350.00
# 3    ETH  sell    10.0   300.00
# 4   DOGE  sell  3000.0     0.15
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# new_df['amount'].plot(kind='hist', bins=20, title='amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# new_df['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# new_df.groupby('symbol').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# new_df.groupby('type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# new_df.plot(kind='scatter', x='amount', y='price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# new_df['amount'].plot(kind='line', figsize=(8, 4), title='amount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# new_df['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['type'].value_counts()
#     for x_label, grp in new_df.groupby('symbol')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('symbol')
# _ = plt.ylabel('type')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(new_df['symbol'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(new_df, x='amount', y='symbol', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(new_df['type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(new_df, x='amount', y='type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(new_df['symbol'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(new_df, x='price', y='symbol', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(new_df['type'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(new_df, x='price', y='type', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
new_df.reset_index()
# Out:
#    index symbol  type  amount    price
# 0      0   DOGE   buy  5000.0     0.20
# 1      1    BTC   buy    10.0  6000.00
# 2      2    BTC   buy     2.5  5900.00
# 3      3   DOGE  sell  3000.0     0.10
# 4      4    BTC  sell     4.0  6200.00
# 5      0    ETH  sell    10.0   400.00
# 6      1    BTC   buy     1.0  5600.00
# 7      2    ETH   buy    20.0   350.00
# 8      3    ETH  sell    10.0   300.00
# 9      4   DOGE  sell  3000.0     0.15

# %%
new_df.reset_index().drop(columns='index')

# %%
new_df.drop?

# %%
# При конкатенации таблицам можно назначать теги чтобы понимать, где какая таблица
pd.concat([operations_old, operations_new], keys=['old', 'new'])

# %%
# Как видно при конкатенации индексы старых таблиц копируются.
# Если вам не нужно это поведение, используйте ignore_index
operations = pd.concat([operations_new, operations_old], ignore_index=True)
operations

# %%
operations_old = pd.DataFrame(
    data=[
        ['DOGE', 'buy', 0.2],
        ['BTC', 'buy', 6000],
        ['BTC', 'buy', 5900],
        ['DOGE', 'sell', 0.1],
        ['BTC', 'sell', 200],
    ],
    columns=['symbol', 'type', 'price']
)
operations_new = pd.DataFrame(
    data=[
        ['ETH', 'sell', 10],
        ['BTC', 'buy', 1],
        ['ETH', 'buy', 20],
        ['ETH', 'sell', 10],
        ['DOGE', 'sell', 3000]
    ],
    columns=['symbol', 'type', 'amount']
)

# %%
operations = pd.concat([operations_new, operations_old], ignore_index=True)
operations

# %% [markdown]
# Данные можно собирать вместе и более умным способом. А именно, вы выбираете какие колонки вас интересуют. Далее если есть записи из двух таблиц у котороых в выбранных колонках значения совпадают мы их "объединяем". Это очень упрощенное объяснение. В pandas эта операция называется merge в SQL - join. Делать объединение можно разными сопособами, поэтому возникает несколько стратегий: left, right, inner и full.

# %%
transactions = pd.DataFrame(
    data=[
        ['DOGE', 'sell', 'Rockfeller'],
        ['DOGE', 'buy', 'J.P. Morgan'],
        ['BTC', 'buy', 'John Doe'],
        ['ADA', 'sell', 'Rick'],
        ['ETH', 'buy', 'Morty']
    ],
    columns=['symbol', 'type', 'user']
)
transactions

# %%
operations

# %%
# Объединение таблиц по типу монеты и операции
# По умолчанию производится inner join остаются записи в которых были полные совпадения
pd.merge(operations, transactions, on=['symbol', 'type'])

# %%
pd.merge(transactions, operations, on=['symbol', 'type'])

# %%
# Левый join таблиц - все записи из первой таблицы остаются и к ним присоединяются записи из правой.
# Аналогично работает правый join
pd.merge(operations, transactions, on=['symbol', 'type'], how='left')

# %%
# Outer join - собираем вместе записи из обеих таблиц
pd.merge(operations, transactions, on=['symbol', 'type'], how='outer')

# %%
pd.merge?

# %%
pd.DataFrame.join?

# %%
del operations_new, operations_old, operations, transactions

# %%
a @ b

# %%
np.dot(a, b) # pd.merge(a, b)

# %%
a.dot(b) # a.join(b)

# %% [markdown]
# # Чтение таблиц

# %% [markdown]
# Чтобы данные анализировать их надо где-то взять. Для этого в pandas есть множество функций. Все их названия начинаются с префикса 'read_'. Мы разберем функцию read_csv.

# %%
# Прочитать таблицу ни о чем не задумываясь
pd.read_csv('coins.csv')

# %%
# Прочитать таблицу и использовать колонку date как индекс
pd.read_csv('coins.csv', index_col='date')

# %%
# Прочитать таблицу и дать pandas подсказки по поводу типов данных в колонках symbol и name
df = pd.read_csv('coins.csv', dtype={'symbol': str, 'name': str, "open": str})

# %%
df.info()

# %% [markdown]
# ## Запись таблиц

# %%
coins = pd.read_csv('coins.csv')

coins.to_csv('file.csv')

# %%
pd.read_csv?

# %%
pd.DataFrame.to_csv?

# %% [markdown]
# # Визуализация

# %% [markdown]
# В pandas есть очень простые средства визуализации. Они подойдут для быстрого анализа, но если хочется сделать красиво и информативно, то вы не по адресу. Любая визуализация делается через аттрибут plot у объекта pandas.Series или pandas.DataFrame.

# %% [markdown]
# Стоит отметить что для отображения графиков нужно использовать магическую команду для jupyter
# ```
# %matplotlib
# ```
# При этом график появится в отдельном окне. Там же будет несколько полезных кнопок для редактирования и сохранения графика. Если хочется чтобы графики отображались прямо в ноутбуке то надо передать аргумент inline
# ```
# %matplotlib inline
# ```

# %%
# %matplotlib inline

# %%
price = pd.DataFrame(
    data=[
        [0.547, 0.745],
        [0.5, 0.964],
        [0.77, 0.718],
        [0.135, 0.845],
        [0.53, None],
        [0.15, 0.795]],
    columns=['ADA', 'DOGE'],
    index=pd.date_range('2018-11-01', periods=6)
)
price

# %%
coins.groupby('symbol').get_group('BTC').price

# %%
coins.groupby('symbol').get_group('BTC').price.plot()

# %%
# Нарисовать график цены монеты ADA.
# Так как индекс в нашей таблице временный, то pandas догадывается, что его можно использовать
# как ось времени на графиках.
price['ADA'].plot()

# %%
# Можно на одном графике нарисовать поведение цены сразу нескольких монет
price[['ADA', 'DOGE']].plot()

# %%
# Цену можно рисовать и в виде столбцовой диаграммы c различными настройками
price.plot.bar(stacked=True)

# %%
# Горизонтальная столбцовая диаграмма
price.plot.barh()

# %%
# Гистограмма
price.plot.hist(bins=3)

# %%
# Ящики с усами
price.plot.box()

# %%
# Графики с заливкой
price.plot.area()

# %%
# Если хочется нарисовать пары каких либо значений в виде точек на плоскости, то подойдет scatter plot
price.plot.scatter(x='ADA', y='DOGE')

# %%
# И на десерт - пирожковая диаграмма
price.plot.pie(subplots=True, figsize=(15,7.5))

# %% [markdown]
# # Другие инструменты работы с данными

# %% [markdown]
# Если ваш датасет не слишком большой, то pandas это де-факто лучший инструмент в наличии. В противном случае есть альтернативы:
#  - [numpy](http://www.numpy.org/) - библиотека для низкоуровневой работы с многомерными массивами из примитивных типов данных. Подходит для "векторизованной" обработки. Numpy - ваш последний шанс все еще писать на обычном питоне, без биндингов на С. Подходит для задач быстрой обработки не слишком больших данных. На самом деле внутри, pandas использует numpy.
#  - [Graphlab](https://turi.com/) - Платная питоновская библиотека для работы как большими данными так и с маленькими датасетами. Данные представляются как SFrame объекты, во многом похожие на DataFrame из pandas.
#  - [Hadoop](https://hadoop.apache.org/) - стек технологии для работы с очень большими данными, в частности есть классический MapReduce.

# %% [markdown]
# # Другие инструменты визуализации

# %% [markdown]
# Для визуализации библиотек намного больше. Вот самые популярные
#  - [Pandas](https://pandas.pydata.org/) - для быстрой и очень простой визуализации. Любая мелкая настройка потребует знания matplotlib
#  - [Seaborn](https://seaborn.pydata.org/) - широкий но фиксированный набор сложных визуализаций с красивыми цветовыми схемами. Библиотека является надстройкой над matplotlib, и, опять же, тонкие настройки потребуют знания matplotlib.
#    - [Галерея с примерами](https://seaborn.pydata.org/examples/index.html)
#    - [Руководство](https://seaborn.pydata.org/tutorial.html)
#  - [ggplot](http://ggplot.yhathq.com/) - многообещающая библиотека скопированная из R. Пока на этапе развития
#  - [Bokeh](https://bokeh.pydata.org/en/latest/) - библиотека для визуализации в web.
#  - [Plot.ly](https://plot.ly/) - библиотека для интерактивных и статических визуализаций. Нацелена на работу в облаке, но можно работать и локально.
#    - [Галерея с примерами](https://plot.ly/python/)
#    - [Краткое введение](https://images.plot.ly/plotly-documentation/images/python_cheat_sheet.pdf)
